# %% [markdown]
# ### 基于PyTorch的图像分类
#
# 该教程以[Image Scene Classification of Multiclass](https://www.kaggle.com/puneet6060/intel-image-classification) 为例，演示了基于PyTorch框架来构建自己的数据集，定义模型，训练分类模型，保存模型，加载模型并推理，将保存的模型利用SageMaker Neo进行编译优化的整个生命周期。
#
# - Kernel: conda_pytorch_latest_p36
# - PyTorch Version: 1.7.1

# %% [markdown]
# #### 步骤一：下载实例数据集（图像分类）
#
# 该数据集为示例数据集，用户在实际使用中可以更换为自己的数据集。

# %%
! rm -rf scenes.zip scenes
! aws s3 cp s3://cloud-edge-ai/datasets/scenes.zip .
! unzip scenes.zip
# Out:
# download: s3://cloud-edge-ai/datasets/scenes.zip to ./scenes.zip
# Archive:  scenes.zip
#    creating: scenes/
#    creating: scenes/seg_test/
#    creating: scenes/seg_test/forest/
#   inflating: scenes/seg_test/forest/23933.jpg
#   inflating: scenes/seg_test/forest/23728.jpg
#   inflating: scenes/seg_test/forest/24047.jpg
#   inflating: scenes/seg_test/forest/23700.jpg
#   inflating: scenes/seg_test/forest/24251.jpg
#   inflating: scenes/seg_test/forest/20779.jpg
#   inflating: scenes/seg_test/forest/23502.jpg
#   inflating: scenes/seg_test/forest/20816.jpg
#   inflating: scenes/seg_test/forest/22973.jpg
#   inflating: scenes/seg_test/forest/23462.jpg
#   inflating: scenes/seg_test/forest/23476.jpg
#   inflating: scenes/seg_test/forest/20619.jpg
#   inflating: scenes/seg_test/forest/22595.jpg
#   inflating: scenes/seg_test/forest/23853.jpg
#   inflating: scenes/seg_test/forest/22542.jpg
#   inflating: scenes/seg_test/forest/23648.jpg
#   inflating: scenes/seg_test/forest/23107.jpg
#   inflating: scenes/seg_test/forest/23852.jpg
#   inflating: scenes/seg_test/forest/23477.jpg
#   inflating: scenes/seg_test/forest/23463.jpg
#   inflating: scenes/seg_test/forest/24324.jpg
#   inflating: scenes/seg_test/forest/23503.jpg
#   inflating: scenes/seg_test/forest/23259.jpg
#   inflating: scenes/seg_test/forest/23067.jpg
#   inflating: scenes/seg_test/forest/21894.jpg
#   inflating: scenes/seg_test/forest/21843.jpg
#   inflating: scenes/seg_test/forest/21855.jpg
#   inflating: scenes/seg_test/forest/21699.jpg
#   inflating: scenes/seg_test/forest/23930.jpg
#   inflating: scenes/seg_test/forest/20544.jpg
#   inflating: scenes/seg_test/forest/23065.jpg
#   inflating: scenes/seg_test/forest/23717.jpg
#   inflating: scenes/seg_test/forest/20785.jpg
#   inflating: scenes/seg_test/forest/22179.jpg
#   inflating: scenes/seg_test/forest/21316.jpg
#   inflating: scenes/seg_test/forest/20801.jpg
#   inflating: scenes/seg_test/forest/21538.jpg
#   inflating: scenes/seg_test/forest/23688.jpg
#   inflating: scenes/seg_test/forest/21921.jpg
#   inflating: scenes/seg_test/forest/24130.jpg
#   inflating: scenes/seg_test/forest/22569.jpg
#   inflating: scenes/seg_test/forest/23663.jpg
#   inflating: scenes/seg_test/forest/23110.jpg
#   inflating: scenes/seg_test/forest/22540.jpg
#   inflating: scenes/seg_train/sea/5506.jpg
#   inflating: scenes/seg_train/sea/8022.jpg
#   inflating: scenes/seg_train/sea/15656.jpg
#   inflating: scenes/seg_train/sea/15124.jpg
#   inflating: scenes/seg_train/sea/10706.jpg
#   inflating: scenes/seg_train/sea/6741.jpg
#   inflating: scenes/seg_train/sea/19865.jpg
#   inflating: scenes/seg_train/sea/15087.jpg
#   inflating: scenes/seg_train/sea/357.jpg
#   inflating: scenes/seg_train/sea/15093.jpg
#   inflating: scenes/seg_train/sea/431.jpg
#   inflating: scenes/seg_train/sea/419.jpg
#   inflating: scenes/seg_train/sea/2484.jpg
#   inflating: scenes/seg_train/sea/20000.jpg
#   inflating: scenes/seg_train/sea/19695.jpg
#   inflating: scenes/seg_train/sea/1172.jpg
#   inflating: scenes/seg_train/sea/13435.jpg
#   inflating: scenes/seg_train/sea/10882.jpg
#   inflating: scenes/seg_train/sea/8156.jpg
#   inflating: scenes/seg_train/sea/15736.jpg
#   inflating: scenes/seg_train/sea/10128.jpg
#   inflating: scenes/seg_train/sea/14366.jpg
#   inflating: scenes/seg_train/sea/7259.jpg
#   inflating: scenes/seg_train/sea/12071.jpg
#   inflating: scenes/seg_train/sea/9506.jpg
#   inflating: scenes/seg_train/sea/10114.jpg
#   inflating: scenes/seg_train/sea/14825.jpg
#   inflating: scenes/seg_train/sea/9937.jpg
#   inflating: scenes/seg_train/sea/14831.jpg
#   inflating: scenes/seg_train/sea/19483.jpg
#   inflating: scenes/seg_train/sea/97.jpg
#   inflating: scenes/seg_train/sea/13804.jpg
#   inflating: scenes/seg_train/sea/11746.jpg
#   inflating: scenes/seg_train/sea/18776.jpg
#   inflating: scenes/seg_train/sea/3215.jpg
#   inflating: scenes/seg_train/sea/8340.jpg
#   inflating: scenes/seg_train/sea/19454.jpg
#   inflating: scenes/seg_train/sea/14170.jpg
#   inflating: scenes/seg_train/sea/2137.jpg
#   inflating: scenes/seg_train/sea/8344.jpg
#   inflating: scenes/seg_train/sea/6369.jpg
#   inflating: scenes/seg_train/sea/11030.jpg
#   inflating: scenes/seg_train/sea/2669.jpg
#   inflating: scenes/seg_train/sea/8422.jpg
#   inflating: scenes/seg_train/sea/7711.jpg
#   inflating: scenes/seg_train/sea/78.jpg
#   inflating: scenes/seg_train/sea/5884.jpg
#   inflating: scenes/seg_train/sea/804.jpg
#   inflating: scenes/seg_train/sea/12511.jpg
#   inflating: scenes/seg_train/sea/16944.jpg
#   inflating: scenes/seg_train/sea/16788.jpg
#   inflating: scenes/seg_train/sea/13828.jpg
#   inflating: scenes/seg_train/sea/623.jpg
#   inflating: scenes/seg_train/sea/87.jpg
#   inflating: scenes/seg_train/sea/17657.jpg
#   inflating: scenes/seg_train/sea/5310.jpg
#   inflating: scenes/seg_train/sea/5338.jpg
#   inflating: scenes/seg_train/sea/3749.jpg
#   inflating: scenes/seg_train/sea/17680.jpg
#   inflating: scenes/seg_train/sea/15097.jpg
#   inflating: scenes/seg_train/sea/8185.jpg
#   inflating: scenes/seg_train/sea/4973.jpg
#   inflating: scenes/seg_train/sea/20010.jpg
#   inflating: scenes/seg_train/sea/3952.jpg
#   inflating: scenes/seg_train/sea/582.jpg
#   inflating: scenes/seg_train/sea/3601.jpg
#   inflating: scenes/seg_train/sea/5270.jpg
#   inflating: scenes/seg_train/sea/5516.jpg
#   inflating: scenes/seg_train/sea/17045.jpg
#   inflating: scenes/seg_train/sea/19068.jpg
#   inflating: scenes/seg_train/sea/3615.jpg
#   inflating: scenes/seg_train/sea/6745.jpg
#   inflating: scenes/seg_train/sea/9310.jpg
#   inflating: scenes/seg_train/sea/1980.jpg
#   inflating: scenes/seg_train/sea/19732.jpg
#   inflating: scenes/seg_train/sea/11385.jpg
#   inflating: scenes/seg_train/sea/6962.jpg
#   inflating: scenes/seg_train/sea/16398.jpg
#   inflating: scenes/seg_train/sea/15691.jpg
#   inflating: scenes/seg_train/sea/15875.jpg
#   inflating: scenes/seg_train/sea/569.jpg
#   inflating: scenes/seg_train/sea/8230.jpg
#   inflating: scenes/seg_train/sea/5714.jpg
#   inflating: scenes/seg_train/sea/9648.jpg
#   inflating: scenes/seg_train/sea/18612.jpg
#   inflating: scenes/seg_train/sea/11150.jpg
#   inflating: scenes/seg_train/sea/6221.jpg
#   inflating: scenes/seg_train/sea/12471.jpg
#   inflating: scenes/seg_train/sea/7659.jpg
#   inflating: scenes/seg_train/sea/17509.jpg
#   inflating: scenes/seg_train/sea/9106.jpg
#   inflating: scenes/seg_train/sea/12303.jpg
#   inflating: scenes/seg_train/sea/16165.jpg
#   inflating: scenes/seg_train/sea/13948.jpg
#   inflating: scenes/seg_train/sea/10299.jpg
#   inflating: scenes/seg_train/sea/13784.jpg
#   inflating: scenes/seg_train/sea/14955.jpg
#   inflating: scenes/seg_train/sea/18835.jpg
#   inflating: scenes/seg_train/sea/4386.jpg
#   inflating: scenes/seg_train/sea/6591.jpg
#   inflating: scenes/seg_train/sea/19294.jpg
#   inflating: scenes/seg_train/sea/11804.jpg
#   inflating: scenes/seg_train/sea/13785.jpg
#   inflating: scenes/seg_train/sea/15486.jpg
#   inflating: scenes/seg_train/sea/17291.jpg
#   inflating: scenes/seg_train/sea/11186.jpg
#   inflating: scenes/seg_train/sea/2907.jpg
#   inflating: scenes/seg_train/sea/19531.jpg
#   inflating: scenes/seg_train/sea/2052.jpg
#   inflating: scenes/seg_train/sea/4423.jpg
#   inflating: scenes/seg_train/sea/12316.jpg
#   inflating: scenes/seg_train/sea/15479.jpg
#   inflating: scenes/seg_train/sea/4437.jpg
#   inflating: scenes/seg_train/sea/795.jpg
#   inflating: scenes/seg_train/sea/6208.jpg
#   inflating: scenes/seg_train/sea/10529.jpg
#   inflating: scenes/seg_train/sea/17246.jpg
#   inflating: scenes/seg_train/sea/781.jpg
#   inflating: scenes/seg_train/sea/7664.jpg
#   inflating: scenes/seg_train/sea/15874.jpg
#   inflating: scenes/seg_train/sea/6793.jpg
#   inflating: scenes/seg_train/sea/4184.jpg
#   inflating: scenes/seg_train/sea/19928.jpg
#   inflating: scenes/seg_train/sea/6787.jpg
#   inflating: scenes/seg_train/sea/15860.jpg
#   inflating: scenes/seg_train/sea/17087.jpg
#   inflating: scenes/seg_train/sea/11390.jpg
#   inflating: scenes/seg_train/sea/540.jpg
#   inflating: scenes/seg_train/sea/10071.jpg
#   inflating: scenes/seg_train/sea/3628.jpg
#   inflating: scenes/seg_train/sea/6750.jpg
#   inflating: scenes/seg_train/sea/6744.jpg
#   inflating: scenes/seg_train/sea/16372.jpg
#   inflating: scenes/seg_train/sea/9339.jpg
#   inflating: scenes/seg_train/sea/12882.jpg
#   inflating: scenes/seg_train/sea/17722.jpg
#   inflating: scenes/seg_train/sea/5271.jpg
#   inflating: scenes/seg_train/sea/11347.jpg
#   inflating: scenes/seg_train/sea/6778.jpg
#   inflating: scenes/seg_train/sea/5488.jpg
#   inflating: scenes/seg_train/sea/11582.jpg
#   inflating: scenes/seg_train/sea/17695.jpg
#   inflating: scenes/seg_train/sea/15096.jpg
#   inflating: scenes/seg_train/sea/6142.jpg
#   inflating: scenes/seg_train/sea/3984.jpg
#   inflating: scenes/seg_train/sea/18559.jpg
#   inflating: scenes/seg_train/sea/6624.jpg
#   inflating: scenes/seg_train/sea/9503.jpg
#   inflating: scenes/seg_train/sea/12706.jpg
#   inflating: scenes/seg_train/sea/4027.jpg
#   inflating: scenes/seg_train/sea/2456.jpg
#   inflating: scenes/seg_train/sea/16206.jpg
#   inflating: scenes/seg_train/sea/14411.jpg
#   inflating: scenes/seg_train/sea/2318.jpg
#   inflating: scenes/seg_train/sea/10887.jpg
#   inflating: scenes/seg_train/sea/12048.jpg
#   inflating: scenes/seg_train/sea/8153.jpg
#   inflating: scenes/seg_train/sea/11233.jpg
#   inflating: scenes/seg_train/sea/15055.jpg
#   inflating: scenes/seg_train/sea/391.jpg
#   inflating: scenes/seg_train/sea/18940.jpg
#   inflating: scenes/seg_train/sea/178.jpg
#   inflating: scenes/seg_train/sea/8392.jpg
#   inflating: scenes/seg_train/sea/11794.jpg
#   inflating: scenes/seg_train/sea/15294.jpg
#   inflating: scenes/seg_train/sea/3238.jpg
#   inflating: scenes/seg_train/sea/19323.jpg
#   inflating: scenes/seg_train/sea/5649.jpg
#   inflating: scenes/seg_train/sea/6354.jpg
#   inflating: scenes/seg_train/sea/2132.jpg
#   inflating: scenes/seg_train/sea/4225.jpg
#   inflating: scenes/seg_train/sea/9701.jpg
#   inflating: scenes/seg_train/sea/6432.jpg
#   inflating: scenes/seg_train/sea/3562.jpg
#   inflating: scenes/seg_train/sea/15243.jpg
#   inflating: scenes/seg_train/sea/11743.jpg
#   inflating: scenes/seg_train/sea/193.jpg
#   inflating: scenes/seg_train/sea/6368.jpg
#   inflating: scenes/seg_train/sea/2668.jpg
#   inflating: scenes/seg_train/sea/4569.jpg
#   inflating: scenes/seg_train/sea/1377.jpg
#   inflating: scenes/seg_train/sea/7706.jpg
#   inflating: scenes/seg_train/sea/16748.jpg
#   inflating: scenes/seg_train/sea/11033.jpg
#   inflating: scenes/seg_train/sea/5105.jpg
#   inflating: scenes/seg_train/sea/16984.jpg
#   inflating: scenes/seg_train/sea/7712.jpg
#   inflating: scenes/seg_train/sea/5663.jpg
#   inflating: scenes/seg_train/sea/4555.jpg
#   inflating: scenes/seg_train/sea/18995.jpg
#   inflating: scenes/seg_train/sea/19453.jpg
#   inflating: scenes/seg_train/sea/2656.jpg
#   inflating: scenes/seg_train/sea/17318.jpg
#   inflating: scenes/seg_train/sea/1.jpg
#   inflating: scenes/seg_train/sea/14836.jpg
#   inflating: scenes/seg_train/sea/6381.jpg
#   inflating: scenes/seg_train/sea/19484.jpg
#   inflating: scenes/seg_train/sea/19490.jpg
#   inflating: scenes/seg_train/sea/7935.jpg
#   inflating: scenes/seg_train/sea/90.jpg
#   inflating: scenes/seg_train/sea/15043.jpg
#   inflating: scenes/seg_train/sea/1175.jpg
#   inflating: scenes/seg_train/sea/11543.jpg
#   inflating: scenes/seg_train/sea/3010.jpg
#   inflating: scenes/seg_train/sea/12738.jpg
#   inflating: scenes/seg_train/sea/14349.jpg
#   inflating: scenes/seg_train/sea/5307.jpg
#   inflating: scenes/seg_train/sea/18573.jpg
#   inflating: scenes/seg_train/sea/17668.jpg
#   inflating: scenes/seg_train/sea/5449.jpg
#   inflating: scenes/seg_train/sea/14407.jpg
#   inflating: scenes/seg_train/sea/4025.jpg
#   inflating: scenes/seg_train/sea/10846.jpg
#   inflating: scenes/seg_train/sea/19876.jpg
#   inflating: scenes/seg_train/sea/17683.jpg
#   inflating: scenes/seg_train/sea/18598.jpg
#   inflating: scenes/seg_train/sea/4794.jpg
#   inflating: scenes/seg_train/sea/4958.jpg
#   inflating: scenes/seg_train/sea/6197.jpg
#   inflating: scenes/seg_train/sea/11351.jpg
#   inflating: scenes/seg_train/sea/2508.jpg
#   inflating: scenes/seg_train/sea/12658.jpg
#   inflating: scenes/seg_train/sea/15651.jpg
#   inflating: scenes/seg_train/sea/5501.jpg
#   inflating: scenes/seg_train/sea/7302.jpg
#   inflating: scenes/seg_train/sea/10715.jpg
#   inflating: scenes/seg_train/sea/16364.jpg
#   inflating: scenes/seg_train/sea/9307.jpg
#   inflating: scenes/seg_train/sea/14573.jpg
#   inflating: scenes/seg_train/sea/12116.jpg
#   inflating: scenes/seg_train/sea/9313.jpg
#   inflating: scenes/seg_train/sea/3158.jpg
#   inflating: scenes/seg_train/sea/9475.jpg
#   inflating: scenes/seg_train/sea/12843.jpg
#   inflating: scenes/seg_train/sea/224.jpg
#   inflating: scenes/seg_train/sea/4810.jpg
#   inflating: scenes/seg_train/sea/4186.jpg
#   inflating: scenes/seg_train/sea/6791.jpg
#   inflating: scenes/seg_train/sea/1798.jpg
#   inflating: scenes/seg_train/sea/2291.jpg
#   inflating: scenes/seg_train/sea/4838.jpg
#   inflating: scenes/seg_train/sea/5703.jpg
#   inflating: scenes/seg_train/sea/15453.jpg
#   inflating: scenes/seg_train/sea/8541.jpg
#   inflating: scenes/seg_train/sea/10259.jpg
#   inflating: scenes/seg_train/sea/5071.jpg
#   inflating: scenes/seg_train/sea/8233.jpg
#   inflating: scenes/seg_train/sea/15447.jpg
#   inflating: scenes/seg_train/sea/6236.jpg
#   inflating: scenes/seg_train/sea/12300.jpg
#   inflating: scenes/seg_train/sea/19255.jpg
#   inflating: scenes/seg_train/sea/10271.jpg
#   inflating: scenes/seg_train/sea/19533.jpg
#   inflating: scenes/seg_train/sea/12466.jpg
#   inflating: scenes/seg_train/sea/6550.jpg
#   inflating: scenes/seg_train/sea/8569.jpg
#   inflating: scenes/seg_train/sea/7882.jpg
#   inflating: scenes/seg_train/sea/12314.jpg
#   inflating: scenes/seg_train/sea/9850.jpg
#   inflating: scenes/seg_train/sea/11184.jpg
#   inflating: scenes/seg_train/sea/7699.jpg
#   inflating: scenes/seg_train/sea/19282.jpg
#   inflating: scenes/seg_train/sea/5931.jpg
#   inflating: scenes/seg_train/sea/2086.jpg
#   inflating: scenes/seg_train/sea/11807.jpg
#   inflating: scenes/seg_train/sea/7868.jpg
#   inflating: scenes/seg_train/sea/2723.jpg
#   inflating: scenes/seg_train/sea/9676.jpg
#   inflating: scenes/seg_train/sea/6237.jpg
#   inflating: scenes/seg_train/sea/4346.jpg
#   inflating: scenes/seg_train/sea/5716.jpg
#   inflating: scenes/seg_train/sea/4408.jpg
#   inflating: scenes/seg_train/sea/8232.jpg
#   inflating: scenes/seg_train/sea/1570.jpg
#   inflating: scenes/seg_train/sea/11152.jpg
#   inflating: scenes/seg_train/sea/796.jpg
#   inflating: scenes/seg_train/sea/19081.jpg
#   inflating: scenes/seg_train/sea/3824.jpg
#   inflating: scenes/seg_train/sea/8965.jpg
#   inflating: scenes/seg_train/sea/14599.jpg
#   inflating: scenes/seg_train/sea/6960.jpg
#   inflating: scenes/seg_train/sea/4805.jpg
#   inflating: scenes/seg_train/sea/12671.jpg
#   inflating: scenes/seg_train/sea/4144.jpg
#   inflating: scenes/seg_train/sea/12665.jpg
#   inflating: scenes/seg_train/sea/9306.jpg
#   inflating: scenes/seg_train/sea/1982.jpg
#   inflating: scenes/seg_train/sea/4622.jpg
#   inflating: scenes/seg_train/sea/13235.jpg
#   inflating: scenes/seg_train/sea/18360.jpg
#   inflating: scenes/seg_train/sea/15122.jpg
#   inflating: scenes/seg_train/sea/1014.jpg
#   inflating: scenes/seg_train/sea/580.jpg
#   inflating: scenes/seg_train/sea/14228.jpg
#   inflating: scenes/seg_train/sea/3950.jpg
#   inflating: scenes/seg_train/sea/19693.jpg
#   inflating: scenes/seg_train/sea/3944.jpg
#   inflating: scenes/seg_train/sea/15903.jpg
#   inflating: scenes/seg_train/sea/13382.jpg
#   inflating: scenes/seg_train/sea/345.jpg
#   inflating: scenes/seg_train/sea/16563.jpg
#   inflating: scenes/seg_train/sea/9514.jpg
#   inflating: scenes/seg_train/sea/19122.jpg
#   inflating: scenes/seg_train/sea/16211.jpg
#   inflating: scenes/seg_train/sea/7505.jpg
#   inflating: scenes/seg_train/sea/386.jpg
#   inflating: scenes/seg_train/sea/2870.jpg
#   inflating: scenes/seg_train/sea/11797.jpg
#   inflating: scenes/seg_train/sea/11783.jpg
#   inflating: scenes/seg_train/sea/13194.jpg
#   inflating: scenes/seg_train/sea/2864.jpg
#   inflating: scenes/seg_train/sea/3549.jpg
#   inflating: scenes/seg_train/sea/16013.jpg
#   inflating: scenes/seg_train/sea/10304.jpg
#   inflating: scenes/seg_train/sea/4232.jpg
#   inflating: scenes/seg_train/sea/7713.jpg
#   inflating: scenes/seg_train/sea/5104.jpg
#   inflating: scenes/seg_train/sea/11754.jpg
#   inflating: scenes/seg_train/sea/5662.jpg
#   inflating: scenes/seg_train/sea/9058.jpg
#   inflating: scenes/seg_train/sea/12249.jpg
#   inflating: scenes/seg_train/sea/17331.jpg
#   inflating: scenes/seg_train/sea/11026.jpg
#   inflating: scenes/seg_train/sea/3561.jpg

# %% [markdown]
# #### 步骤二：构建自定义数据集
#
# 构建PyTorch的自定义数据集类，该类会被用来被DataLoader加载，进行模型训练和迭代。

# %%
import os
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision.io import read_image
from torchvision.transforms import Lambda, transforms


class CustomImageDataset(Dataset):
    def __init__(self, images_root_dir, transform=None, target_transform=None):
        """
        Constructor of customized image dataset

        :param images_root_dir: root directory of images
        :param transform: transform handler for input images
        :param target_transform: transform handler for ground truth
        """
        self._images_root_dir = images_root_dir
        self._transform = transform
        self._target_transform = target_transform
        self._samples = self.collect_samples()

    @staticmethod
    def name2id(name):
        name_id_lut = {"buildings": 0, "forest": 1, "glacier": 2, "mountain": 3, "sea": 4, "street": 5}
        return name_id_lut[name]

    @staticmethod
    def id2name(cls_id):
        id_name_lut = {0: "buildings", 1: "forest", 2: "glacier", 3: "mountain", 4: "sea", 5: "street"}
        return id_name_lut[cls_id]

    def collect_samples(self):
        """
        collect all samples including both input images and ground truth labels

        :return: list of samples
        """
        samples = list()
        cls_names = os.listdir(self._images_root_dir)
        for cls_name in cls_names:
            cls_folder_root_dir = os.path.join(self._images_root_dir, cls_name)
            image_names = [name for name in os.listdir(cls_folder_root_dir) if name.endswith(".jpg")]

            for image_name in image_names:
                image_full_path = os.path.join(cls_folder_root_dir, image_name)
                label = self.name2id(cls_name)
                samples.append({"image_full_path": image_full_path, "label": label})

        return samples

    def __len__(self):
        return len(self._samples)

    def __getitem__(self, idx):
        image_full_path = self._samples[idx]["image_full_path"]
        label = self._samples[idx]["label"]
        image = read_image(image_full_path)     # tensor, torch.uint8

        if self._transform:
            image = self._transform(image)
        if self._target_transform:
            label = self._target_transform(label)
        return image, label

# %% [markdown]
# #### 步骤三：定义图像分类网络模型
#
# 定义图像分类网络模型，此处以resnet50为Backbone，后面级联全连接层。

# %%
import torch
from torch import nn
from torchvision import models


class CustomClassificationModel(nn.Module):
    def __init__(self):
        super(CustomClassificationModel, self).__init__()

        self._model = models.resnet50(pretrained=True)

        # adapt the last fully connected layer to customized dataset
        fc_inputs = self._model.fc.in_features
        self._model.fc = nn.Sequential(
            nn.Linear(fc_inputs, 256),
            nn.ReLU(),
            nn.Linear(256, 6)           # output dimension 6 should be the same with our classification task
        )

    def forward(self, x):
        logits = self._model(x)
        probs = torch.nn.Softmax(dim=1)(logits)
        return logits, probs

# %% [markdown]
# #### 步骤四：定义训练和验证脚本
#
# 定义训练脚本和验证脚本。

# %%
import torch
from torch.utils.data import DataLoader
from torchvision.transforms import transforms


def train(dataloader, model, loss_fn, optimizer, device):
    """
    training module

    :param dataloader: training data loader
    :param model: customized model
    :param loss_fn: loss function handler
    :param optimizer: neural network learning optimizer
    :param device: device, "cpu" or "cuda"
    :return:
    """
    samples_amount = len(dataloader.dataset)
    model.train()
    for batch_idx, (input_image_batch, input_gt_batch) in enumerate(dataloader):
        input_image_batch = input_image_batch.to(device)
        input_gt_batch = input_gt_batch.to(device)

        # compute loss
        logits, probs = model(input_image_batch)
        loss = loss_fn(logits, input_gt_batch)

        # loss back-propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_idx % 10 == 0:
            loss, current = loss.item(), batch_idx * len(input_image_batch)
            print(f"loss: {loss:>7f}  [{current:>5d}/{samples_amount:>5d}]")


def test(dataloader, model, loss_fn, device):
    """
    test module

    :param dataloader: test data loader
    :param model: customized model
    :param loss_fn: loss function handler
    :param device: device, "cpu" or "cuda"
    :return:
    """
    samples_amount = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0.0, 0.0
    with torch.no_grad():
        for input_image_batch, input_gt_batch in dataloader:
            input_image_batch = input_image_batch.to(device)
            input_gt_batch = input_gt_batch.to(device)

            logits, probs = model(input_image_batch)
            test_loss += loss_fn(logits, input_gt_batch).item()

            correct += (probs.argmax(1) == input_gt_batch).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= samples_amount
    print(f"Test Performance: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %% [markdown]
# #####  步骤五：开始训练
#
# 开启模型训练，设置Batch尺寸为64，输入图片大小为224x224，训练迭代周期为5个Epochs。

# %%
# STEP 1: DEFINE DATASET
batch_size = 128
channels = 3
height = 224
width = 224

transform = transforms.Compose([                # image preprocess
    transforms.Resize(size=256),                # resize the short edge to 256 with its original height/width ratio
    transforms.CenterCrop(size=(height, width)),# (h, w)
    transforms.ConvertImageDtype(torch.float),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],             # RGB
        std=[0.229, 0.224, 0.225]               # RGB
    )
])

train_data = CustomImageDataset(images_root_dir="./scenes/seg_train",
                                transform=transform,
                                target_transform=None)
test_data = CustomImageDataset(images_root_dir="./scenes/seg_test",
                               transform=transform,
                               target_transform=None)

train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

print("There are totally {} samples in training dataset.".format(len(train_data)))
print("There are totally {} samples in test dataset.".format(len(test_data)))
print("Training Batches = {}".format(len(train_dataloader)))
print("Test Batches = {}".format(len(test_dataloader)))

# STEP 2: DEFINE MODEL
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} device')

custom_model = CustomClassificationModel().to(device)

# STEP 3: START TRAINING
adam_optimizer = torch.optim.Adam(custom_model.parameters(), lr=1e-4)
loss_handler = torch.nn.CrossEntropyLoss()

max_epochs = 5
for epoch_idx in range(max_epochs):
    print(f"Epoch {epoch_idx + 1}\n-------------------------------")
    train(train_dataloader, custom_model, loss_fn=loss_handler, optimizer=adam_optimizer, device=device)
    test(test_dataloader, custom_model, loss_fn=loss_handler, device=device)
print("Done!")
# Out:
# There are totally 14034 samples in training dataset.
# There are totally 3000 samples in test dataset.
# Training Batches = 110
# Test Batches = 24
# Using cuda device
# Epoch 1
# -------------------------------
# loss: 1.776816  [    0/14034]
# loss: 0.600790  [ 1280/14034]
# loss: 0.197847  [ 2560/14034]
# loss: 0.139853  [ 3840/14034]
# loss: 0.248808  [ 5120/14034]
# loss: 0.182705  [ 6400/14034]
# loss: 0.237829  [ 7680/14034]
# loss: 0.173471  [ 8960/14034]
# loss: 0.221113  [10240/14034]
# loss: 0.191452  [11520/14034]
# loss: 0.116594  [12800/14034]
# Test Performance:
#  Accuracy: 92.3%, Avg loss: 0.211806
#
# Epoch 2
# -------------------------------
# loss: 0.147761  [    0/14034]
# loss: 0.191582  [ 1280/14034]
# loss: 0.058937  [ 2560/14034]
# loss: 0.188325  [ 3840/14034]
# loss: 0.094238  [ 5120/14034]
# loss: 0.165309  [ 6400/14034]
# loss: 0.154400  [ 7680/14034]
# loss: 0.242172  [ 8960/14034]
# loss: 0.207623  [10240/14034]
# loss: 0.173794  [11520/14034]
# loss: 0.162673  [12800/14034]
# Test Performance:
#  Accuracy: 93.1%, Avg loss: 0.192581
#
# Epoch 3
# -------------------------------
# loss: 0.118286  [    0/14034]
# loss: 0.031894  [ 1280/14034]
# loss: 0.072410  [ 2560/14034]
# loss: 0.127486  [ 3840/14034]
# loss: 0.051660  [ 5120/14034]
# loss: 0.055986  [ 6400/14034]
# loss: 0.061657  [ 7680/14034]
# loss: 0.025608  [ 8960/14034]
# loss: 0.111727  [10240/14034]
# loss: 0.135448  [11520/14034]
# loss: 0.065408  [12800/14034]
# Test Performance:
#  Accuracy: 93.1%, Avg loss: 0.222787
#
# Epoch 4
# -------------------------------
# loss: 0.029222  [    0/14034]
# loss: 0.013209  [ 1280/14034]
# loss: 0.022907  [ 2560/14034]
# loss: 0.106879  [ 3840/14034]
# loss: 0.032599  [ 5120/14034]
# loss: 0.061038  [ 6400/14034]
# loss: 0.020345  [ 7680/14034]
# loss: 0.063283  [ 8960/14034]
# loss: 0.083310  [10240/14034]
# loss: 0.011553  [11520/14034]
# loss: 0.032842  [12800/14034]
# Test Performance:
#  Accuracy: 92.0%, Avg loss: 0.305021
#
# Epoch 5
# -------------------------------
# loss: 0.022427  [    0/14034]
# loss: 0.045882  [ 1280/14034]
# loss: 0.038503  [ 2560/14034]
# loss: 0.040792  [ 3840/14034]
# loss: 0.010516  [ 5120/14034]
# loss: 0.009030  [ 6400/14034]
# loss: 0.034797  [ 7680/14034]
# loss: 0.012115  [ 8960/14034]
# loss: 0.027655  [10240/14034]
# loss: 0.040439  [11520/14034]
# loss: 0.004927  [12800/14034]
# Test Performance:
#  Accuracy: 92.8%, Avg loss: 0.289625
#
# Done!

# %% [markdown]
# #### 步骤六：保存模型
#
# 保存训练完成的模型，用来推理时加载，或用来SageMaker Neo优化。

# %%
custom_model.eval()
inp = torch.rand(1, channels, height, width).to(device)
model_trace = torch.jit.trace(custom_model, inp)

# Save your model. The following code saves it with the .pth file extension
model_trace.save('scenes.pth')
print("Saved PyTorch Model State to scenes.pth")
# Out:
# Saved PyTorch Model State to scenes.pth

# %% [markdown]
# #### 步骤七： 加载模型进行前向推理
#
# 加载训练完成的图像分类模型，用其来对输入的照片进行实时推理，该部分代码逻辑在云端部署阶段会被封装在Docker镜像中。

# %%
# 单张图片推理调用示例
import time
from torchvision.io import read_image
from torchvision.transforms import transforms


test_transform = transforms.Compose([               # image preprocess
    transforms.Resize(size=256),                    # resize the short edge to 256 with its original height/width ratio
    transforms.CenterCrop(size=(height, width)),    # (h, w)
    transforms.ConvertImageDtype(torch.float),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],                 # RGB
        std=[0.229, 0.224, 0.225]                   # RGB
    )
])


device = 'cuda' if torch.cuda.is_available() else 'cpu'
test_image_full_path = "./scenes/seg_test/buildings/20057.jpg"     # your test image full path
image = read_image(test_image_full_path)                           # load the test image
print("raw image's shape = {}".format(image.shape))

model_path = "./scenes.pth"                                        # specify the model weights
loaded_model = torch.jit.load(model_path)                          # load pre-trained model
loaded_model.eval()                                                # configure it as inference mode

run_times = 500

t1 = time.time()
for _ in range(run_times):
    model_input = test_transform(image)
    model_input = model_input[None, :]
    model_input = model_input.to(device)
    logits, probs = loaded_model(model_input)
t2 = time.time()

probs = probs.detach().cpu().numpy()

print("Time cost for each inference (224x224x3 input size) = {} ms".format(1000 * (t2 - t1) / run_times))
print("probs = {}".format(probs))
print("probs.shape = {}".format(probs.shape))
# Out:
# raw image's shape = torch.Size([3, 150, 150])
# Time cost for each inference (224x224x3 input size) = 8.174571514129639 ms
# probs = [[9.9998665e-01 2.2544393e-06 1.7872766e-06 1.4021286e-06 3.7337682e-06
#   4.2009960e-06]]
# probs.shape = (1, 6)

# %% [markdown]
# #### 步骤八：保存模型供SageMaker Neo优化

# %%
import tarfile

# Save as a compressed tar file
import tarfile
with tarfile.open('scenes.tar.gz', 'w:gz') as f:
    f.add('scenes.pth')
f.close()

# %%
! aws s3 cp scenes.tar.gz s3://neo-models-zoo/input/classification/scenes.tar.gz
# Out:
# upload: ./scenes.tar.gz to s3://neo-models-zoo/input/classification/scenes.tar.gz

# %% [markdown]
# #### 步骤九：基于SageMaker Neo对预先训练好的模型进行编译优化

# %%
import time
import uuid
import boto3
from sagemaker import get_execution_role

role = get_execution_role()
sagemaker_client = boto3.client('sagemaker', region_name='us-east-1')

# define configuration
s3_input_location = f"s3://neo-models-zoo/input/classification/scenes.tar.gz"
s3_output_location = f"s3://neo-models-zoo/output/jetson_nano/classification/"

framework = 'PyTorch'
data_shape = '{"data": [1, 3, 224, 224]}'
target_device = 'jetson_nano'


# specify the compilation job
compilation_job_name = 'cls-task-{}'.format(uuid.uuid4())
print(f'Compilation job for {compilation_job_name} started')

response = sagemaker_client.create_compilation_job(
    CompilationJobName=compilation_job_name,
    RoleArn=role,
    InputConfig={
        'S3Uri': s3_input_location,
        'DataInputConfig': data_shape,
        'Framework': framework.upper()
    },
    OutputConfig={
        'S3OutputLocation': s3_output_location,
        'TargetDevice': target_device 
    },
    StoppingCondition={
        'MaxRuntimeInSeconds': 900
    }
)


while True:
    response = sagemaker_client.describe_compilation_job(CompilationJobName=compilation_job_name)
    if response['CompilationJobStatus'] == 'COMPLETED':
        break
    elif response['CompilationJobStatus'] == 'FAILED':
        print("Response = {}".format(response))
        raise RuntimeError('Compilation failed')
    print('Compiling ...')
    time.sleep(30)
print('Done!')

print("Response = {}".format(response))
# Out:
# Compilation job for cls-task-440419a7-f2c3-4111-8a32-006bc82392d3 started
# Compiling ...
# Compiling ...
# Compiling ...
# Compiling ...
# Compiling ...
# Compiling ...
# Compiling ...
# Compiling ...
# Compiling ...
# Done!
# Response = {'CompilationJobName': 'cls-task-440419a7-f2c3-4111-8a32-006bc82392d3', 'CompilationJobArn': 'arn:aws:sagemaker:us-east-1:406855020396:compilation-job/cls-task-440419a7-f2c3-4111-8a32-006bc82392d3', 'CompilationJobStatus': 'COMPLETED', 'CompilationStartTime': datetime.datetime(2021, 11, 23, 7, 56, 34, tzinfo=tzlocal()), 'CompilationEndTime': datetime.datetime(2021, 11, 23, 7, 59, 1, tzinfo=tzlocal()), 'StoppingCondition': {'MaxRuntimeInSeconds': 900}, 'CreationTime': datetime.datetime(2021, 11, 23, 7, 54, 45, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2021, 11, 23, 7, 59, 1, tzinfo=tzlocal()), 'ModelArtifacts': {'S3ModelArtifacts': 's3://neo-models-zoo/output/jetson_nano/classification/scenes-jetson_nano.tar.gz'}, 'ModelDigests': {'ArtifactDigest': 'blake2s:fab27248fed8ecaf409f2e19bd08c87d28d0c2bbd42ada812b7d14b3c435b5ed'}, 'RoleArn': 'arn:aws:iam::406855020396:role/battery-consistency-bias-alarm-prediction-notebook-role', 'InputConfig': {'S3Uri': 's3://neo-models-zoo/input/classification/scenes.tar.gz', 'DataInputConfig': '{"data": [1, 3, 224, 224]}', 'Framework': 'PYTORCH'}, 'OutputConfig': {'S3OutputLocation': 's3://neo-models-zoo/output/jetson_nano/classification/', 'TargetDevice': 'jetson_nano'}, 'ResponseMetadata': {'RequestId': 'c8b39d4d-0d84-47bf-90ed-cdd58e07be6c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'c8b39d4d-0d84-47bf-90ed-cdd58e07be6c', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1014', 'date': 'Tue, 23 Nov 2021 07:59:17 GMT'}, 'RetryAttempts': 0}}

# %%
! aws s3 ls s3://neo-models-zoo/output/jetson_nano/classification/
# Out:
# 2021-11-23 07:58:52   94308041 scenes-jetson_nano.tar.gz

# %%
! aws s3 cp s3://neo-models-zoo/output/jetson_nano/classification/scenes-jetson_nano.tar.gz .
! tar -zxvf scenes-jetson_nano.tar.gz
# Out:
# download: s3://neo-models-zoo/output/jetson_nano/classification/scenes-jetson_nano.tar.gz to ./scenes-jetson_nano.tar.gz
# dlr.h
# libdlr.so
# compiled.meta
# compiled_model.json
# compiled.so
# compiled.params
# manifest
